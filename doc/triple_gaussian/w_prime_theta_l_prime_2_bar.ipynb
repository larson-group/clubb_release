# %%
from itertools import product

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import sympy as sp
from IPython.display import display
from sympy import abc, oo, Rational, init_printing

import checked_functions as c_f
import symbols as sym
init_printing()

# %% [markdown]
# # This document aims to numerically check $\overline{w'\theta_l'^2}$

# %% [markdown]
# ## Define the marginal distributions.

# %%
display(sp.Eq(sym.G_1_w_theta, c_f.G_1_w_theta_density))
# Out:
#                            ⎛        2            2             2
#                           -⎝\sigma_w ⋅\theta_{l1}  - 2⋅\sigma_w ⋅\theta_{l1}⋅θ
#                           ────────────────────────────────────────────────────
#
#
#                          ℯ
# G_{1w\theta}(w,\theta) = ─────────────────────────────────────────────────────
#
#
#
#
#            2  2                       2  2                         2
#  + \sigma_w ⋅θ  + \sigma_{\theta_{l1}} ⋅w  - 2⋅\sigma_{\theta_{l1}} ⋅w⋅w₁ + \s
# ──────────────────────────────────────────────────────────────────────────────
#                    2                     2
#          2⋅\sigma_w ⋅\sigma_{\theta_{l1}}
#
# ──────────────────────────────────────────────────────────────────────────────
#             _________________________________
#            ╱         2                     2
#      2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l1}}
#
#                   2   2⎞
# igma_{\theta_{l1}} ⋅w₁ ⎠
# ─────────────────────────
#
#
#
# ─────────────────────────

# %%
display(sp.Eq(sym.G_2_w_theta, c_f.G_2_w_theta_density))
# Out:
#                            ⎛        2            2             2
#                           -⎝\sigma_w ⋅\theta_{l2}  - 2⋅\sigma_w ⋅\theta_{l2}⋅θ
#                           ────────────────────────────────────────────────────
#
#
#                          ℯ
# G_{2w\theta}(w,\theta) = ─────────────────────────────────────────────────────
#
#
#
#
#            2  2                       2  2                         2
#  + \sigma_w ⋅θ  + \sigma_{\theta_{l2}} ⋅w  - 2⋅\sigma_{\theta_{l2}} ⋅w⋅w₂ + \s
# ──────────────────────────────────────────────────────────────────────────────
#                    2                     2
#          2⋅\sigma_w ⋅\sigma_{\theta_{l2}}
#
# ──────────────────────────────────────────────────────────────────────────────
#             _________________________________
#            ╱         2                     2
#      2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l2}}
#
#                   2   2⎞
# igma_{\theta_{l2}} ⋅w₂ ⎠
# ─────────────────────────
#
#
#
# ─────────────────────────

# %%
display(sp.Eq(sym.G_3_w_theta, c_f.G_3_w_theta_density))
# Out:
#                                              2            2
#                           \overline{\theta_l} ⋅\sigma_{w3}  - 2⋅\overline{\the
#                           ────────────────────────────────────────────────────
#
#
#                          ℯ
# G_{3w\theta}(w,\theta) = ─────────────────────────────────────────────────────
#
#
#
#
#
# ta_l}⋅\overline{w}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3} + 2⋅\overl
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ine{\theta_l}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅w - 2⋅\overline
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                      2⋅\sigma_
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                             2⋅
#
#                       2                 2                    2
# {\theta_l}⋅\sigma_{w3} ⋅θ + \overline{w} ⋅\sigma_{\theta_l 3}  + 2⋅\overline{w
# ──────────────────────────────────────────────────────────────────────────────
#             2            2
# {\theta_l 3} ⋅\sigma_{w3} ⋅(\rho_{w\theta_l} - 1)⋅(\rho_{w\theta_l} + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
#      ___________________________________________________________
#     ╱                    2            2 ⎛                    2⎞
# π⋅╲╱  \sigma_{\theta_l 3} ⋅\sigma_{w3} ⋅⎝1 - \rho_{w\theta_l} ⎠
#
#
# }⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅θ - 2⋅\overline{w}⋅\sigma_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#            2
# \theta_l 3} ⋅w - 2⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅θ⋅w + \sig
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                2  2              2  2
# ma_{\theta_l 3} ⋅w  + \sigma_{w3} ⋅θ
# ─────────────────────────────────────
#
#
#
# ─────────────────────────────────────

# %%
display(sp.Eq(sym.G_w_theta, c_f.G_w_theta, evaluate=False))
# Out:
#                                     ⎛        2            2             2
#                                    -⎝\sigma_w ⋅\theta_{l1}  - 2⋅\sigma_w ⋅\the
#                                    ───────────────────────────────────────────
#
#
#                         α⋅(1 - δ)⋅ℯ
# G_{w\theta}(w,\theta) = ──────────────────────────────────────────────────────
#
#
#
#
#                     2  2                       2  2                         2
# ta_{l1}⋅θ + \sigma_w ⋅θ  + \sigma_{\theta_{l1}} ⋅w  - 2⋅\sigma_{\theta_{l1}} ⋅
# ──────────────────────────────────────────────────────────────────────────────
#                             2                     2
#                   2⋅\sigma_w ⋅\sigma_{\theta_{l1}}
#
# ──────────────────────────────────────────────────────────────────────────────
#                 _________________________________
#                ╱         2                     2
#          2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l1}}
#
#                            2   2⎞                          2            2
# w⋅w₁ + \sigma_{\theta_{l1}} ⋅w₁ ⎠       \overline{\theta_l} ⋅\sigma_{w3}  - 2⋅
# ──────────────────────────────────      ──────────────────────────────────────
#
#
#                                      δ⋅ℯ
# ────────────────────────────────── + ─────────────────────────────────────────
#
#
#
#
#
# \overline{\theta_l}⋅\overline{w}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# w3} + 2⋅\overline{\theta_l}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅w
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                     2                 2                    2
#  - 2⋅\overline{\theta_l}⋅\sigma_{w3} ⋅θ + \overline{w} ⋅\sigma_{\theta_l 3}  +
# ──────────────────────────────────────────────────────────────────────────────
#                           2            2
#      2⋅\sigma_{\theta_l 3} ⋅\sigma_{w3} ⋅(\rho_{w\theta_l} - 1)⋅(\rho_{w\theta
#
# ──────────────────────────────────────────────────────────────────────────────
#                   ___________________________________________________________
#                  ╱                    2            2 ⎛                    2⎞
#            2⋅π⋅╲╱  \sigma_{\theta_l 3} ⋅\sigma_{w3} ⋅⎝1 - \rho_{w\theta_l} ⎠
#
#
#  2⋅\overline{w}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅θ - 2⋅\overli
# ──────────────────────────────────────────────────────────────────────────────
#
# _l} + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                          2
# ne{w}⋅\sigma_{\theta_l 3} ⋅w - 2⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                              2  2              2  2                     ⎛
# w3}⋅θ⋅w + \sigma_{\theta_l 3} ⋅w  + \sigma_{w3} ⋅θ                     -⎝\sigm
# ───────────────────────────────────────────────────                    ───────
#
#
#                                                       (1 - α)⋅(1 - δ)⋅ℯ
# ─────────────────────────────────────────────────── + ────────────────────────
#
#
#
#
#    2            2             2                         2  2
# a_w ⋅\theta_{l2}  - 2⋅\sigma_w ⋅\theta_{l2}⋅θ + \sigma_w ⋅θ  + \sigma_{\theta_
# ──────────────────────────────────────────────────────────────────────────────
#                                                                 2
#                                                       2⋅\sigma_w ⋅\sigma_{\the
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                  _____________________________
#                                                 ╱         2
#                                           2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l2
#
#      2  2                         2                            2   2⎞
# {l2}} ⋅w  - 2⋅\sigma_{\theta_{l2}} ⋅w⋅w₂ + \sigma_{\theta_{l2}} ⋅w₂ ⎠
# ──────────────────────────────────────────────────────────────────────
#         2
# ta_{l2}}
#
# ──────────────────────────────────────────────────────────────────────
# ____
#   2
# }}

# %%
w_prime_theta_l_2_prime_bar = sp.Integral(
    (sp.abc.w - sym.w_bar) * (sp.abc.theta - sym.theta_l_bar) ** 2 * c_f.G_w_theta,
    [sp.abc.w, -oo, oo],
    [sp.abc.theta, -oo, oo])

display(sp.Eq(sym.w_prime_theta_prime_l_2_bar, w_prime_theta_l_2_prime_bar))
# Out:
#                             ∞  ∞
#                             ⌠  ⌠
#                             ⎮  ⎮
#                             ⎮  ⎮
#                             ⎮  ⎮
#                             ⎮  ⎮
#                             ⎮  ⎮
#                             ⎮  ⎮                            2
# \overline{w'\theta'_l}__2 = ⎮  ⎮  (-\overline{\theta_l} + θ) ⋅(-\overline{w} +
#                             ⎮  ⎮
#                             ⎮  ⎮
#                             ⎮  ⎮
#                             ⌡  ⌡
#                             -∞ -∞
#
#
#
#     ⎛            ⎛        2            2             2
#     ⎜           -⎝\sigma_w ⋅\theta_{l1}  - 2⋅\sigma_w ⋅\theta_{l1}⋅θ + \sigma_
#     ⎜           ──────────────────────────────────────────────────────────────
#     ⎜
#     ⎜                                                                        2
#     ⎜α⋅(1 - δ)⋅ℯ
#  w)⋅⎜─────────────────────────────────────────────────────────────────────────
#     ⎜                                                                      ___
#     ⎜                                                                     ╱
#     ⎝                                                               2⋅π⋅╲╱  \s
#
#
#
#
#
#  2  2                       2  2                         2
# w ⋅θ  + \sigma_{\theta_{l1}} ⋅w  - 2⋅\sigma_{\theta_{l1}} ⋅w⋅w₁ + \sigma_{\the
# ──────────────────────────────────────────────────────────────────────────────
#          2                     2
# ⋅\sigma_w ⋅\sigma_{\theta_{l1}}
#
# ──────────────────────────────────────────────────────────────────────────────
# ______________________________
#       2                     2
# igma_w ⋅\sigma_{\theta_{l1}}
#
#
#
#
#
#         2   2⎞                          2            2
# ta_{l1}} ⋅w₁ ⎠       \overline{\theta_l} ⋅\sigma_{w3}  - 2⋅\overline{\theta_l}
# ───────────────      ─────────────────────────────────────────────────────────
#
#
#                   δ⋅ℯ
# ─────────────── + ────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# ⋅\overline{w}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3} + 2⋅\overline{\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# theta_l}⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅w - 2⋅\overline{\the
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                 2⋅\sigma_{\the
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                                              _
#                                                                             ╱
#                                                                       2⋅π⋅╲╱
#
#
#
#
#
#                  2                 2                    2
# ta_l}⋅\sigma_{w3} ⋅θ + \overline{w} ⋅\sigma_{\theta_l 3}  + 2⋅\overline{w}⋅\rh
# ──────────────────────────────────────────────────────────────────────────────
#        2            2
# ta_l 3} ⋅\sigma_{w3} ⋅(\rho_{w\theta_l} - 1)⋅(\rho_{w\theta_l} + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
# __________________________________________________________
#                    2            2 ⎛                    2⎞
# \sigma_{\theta_l 3} ⋅\sigma_{w3} ⋅⎝1 - \rho_{w\theta_l} ⎠
#
#
#
#
#
#
# o_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅θ - 2⋅\overline{w}⋅\sigma_{\thet
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#       2
# a_l 3} ⋅w - 2⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅θ⋅w + \sigma_{\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#           2  2              2  2                     ⎛        2            2
# theta_l 3} ⋅w  + \sigma_{w3} ⋅θ                     -⎝\sigma_w ⋅\theta_{l2}  -
# ────────────────────────────────                    ──────────────────────────
#
#
#                                    (1 - α)⋅(1 - δ)⋅ℯ
# ──────────────────────────────── + ───────────────────────────────────────────
#
#
#
#
#
#
#
#
#            2                         2  2                       2  2
#  2⋅\sigma_w ⋅\theta_{l2}⋅θ + \sigma_w ⋅θ  + \sigma_{\theta_{l2}} ⋅w  - 2⋅\sigm
# ──────────────────────────────────────────────────────────────────────────────
#                                              2                     2
#                                    2⋅\sigma_w ⋅\sigma_{\theta_{l2}}
#
# ──────────────────────────────────────────────────────────────────────────────
#                               _________________________________
#                              ╱         2                     2
#                        2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l2}}
#
#
#
#
#
#                2                            2   2⎞ ⎞
# a_{\theta_{l2}} ⋅w⋅w₂ + \sigma_{\theta_{l2}} ⋅w₂ ⎠ ⎟
# ───────────────────────────────────────────────────⎟
#                                                    ⎟
#                                                    ⎟
#                                                    ⎟
# ───────────────────────────────────────────────────⎟ dw dθ
#                                                    ⎟
#                                                    ⎟
#                                                    ⎠

# %%
w_prime_theta_l_2_prime_bar = w_prime_theta_l_2_prime_bar.subs({
    sym.w_bar: c_f.w_bar(),
    sym.theta_l_bar: c_f.theta_l_bar()
})

display(sp.Eq(sym.w_prime_theta_prime_l_2_bar, w_prime_theta_l_2_prime_bar))
# Out:
#                             ∞  ∞
#                             ⌠  ⌠
#                             ⎮  ⎮  ⎛            ⎛        2            2
#                             ⎮  ⎮  ⎜           -⎝\sigma_w ⋅\theta_{l1}  - 2⋅\si
#                             ⎮  ⎮  ⎜           ────────────────────────────────
#                             ⎮  ⎮  ⎜
#                             ⎮  ⎮  ⎜
#                             ⎮  ⎮  ⎜α⋅(1 - δ)⋅ℯ
# \overline{w'\theta'_l}__2 = ⎮  ⎮  ⎜───────────────────────────────────────────
#                             ⎮  ⎮  ⎜
#                             ⎮  ⎮  ⎜
#                             ⎮  ⎮  ⎝
#                             ⌡  ⌡
#                             -∞ -∞
#
#
#
#      2                         2  2                       2  2
# gma_w ⋅\theta_{l1}⋅θ + \sigma_w ⋅θ  + \sigma_{\theta_{l1}} ⋅w  - 2⋅\sigma_{\th
# ──────────────────────────────────────────────────────────────────────────────
#                                        2                     2
#                              2⋅\sigma_w ⋅\sigma_{\theta_{l1}}
#
# ──────────────────────────────────────────────────────────────────────────────
#                            _________________________________
#                           ╱         2                     2
#                     2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l1}}
#
#
#
#
#
#          2                            2   2⎞
# eta_{l1}} ⋅w⋅w₁ + \sigma_{\theta_{l1}} ⋅w₁ ⎠       -2⋅\rho_{w\theta_l}⋅\sigma_
# ─────────────────────────────────────────────      ───────────────────────────
#
#
#                                                 δ⋅ℯ
# ───────────────────────────────────────────── + ──────────────────────────────
#
#
#
#
#
#
#
#
#
# {\theta_l 3}⋅\sigma_{w3}⋅θ⋅w + 2⋅\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# w3}⋅θ⋅(α⋅w₁⋅(1 - δ) + δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₂⋅(1 - α)⋅(1 - δ)) + 2⋅\rho_{w\
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅w⋅(\theta_{l1}⋅α⋅(1 - δ) + \theta_{l2
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# }⋅(1 - α)⋅(1 - δ) + δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α))) - 2⋅\rho_{w\theta
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# _l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅(\theta_{l1}⋅α⋅(1 - δ) + \theta_{l2}⋅(1 -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# α)⋅(1 - δ) + δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)))⋅(α⋅w₁⋅(1 - δ) + δ⋅(α⋅w₁
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2            2
#                             2⋅\sigma_{\theta_l 3} ⋅\sigma_{w3} ⋅(\rho_{w\theta
#
# ──────────────────────────────────────────────────────────────────────────────
#                                           ____________________________________
#                                          ╱                    2            2 ⎛
#                                    2⋅π⋅╲╱  \sigma_{\theta_l 3} ⋅\sigma_{w3} ⋅⎝
#
#
#
#
#
#                                                          2  2
# + w₂⋅(1 - α)) + w₂⋅(1 - α)⋅(1 - δ)) + \sigma_{\theta_l 3} ⋅w  - 2⋅\sigma_{\the
# ──────────────────────────────────────────────────────────────────────────────
#
# _l} - 1)⋅(\rho_{w\theta_l} + 1)
#
# ──────────────────────────────────────────────────────────────────────────────
# _______________________
#                     2⎞
# 1 - \rho_{w\theta_l} ⎠
#
#
#
#
#
#        2
# ta_l 3} ⋅w⋅(α⋅w₁⋅(1 - δ) + δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₂⋅(1 - α)⋅(1 - δ)) + \sigm
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#               2                                                            2
# a_{\theta_l 3} ⋅(α⋅w₁⋅(1 - δ) + δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₂⋅(1 - α)⋅(1 - δ))  +
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#             2  2                2
#  \sigma_{w3} ⋅θ  - 2⋅\sigma_{w3} ⋅θ⋅(\theta_{l1}⋅α⋅(1 - δ) + \theta_{l2}⋅(1 -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                                                                    2
# α)⋅(1 - δ) + δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α))) + \sigma_{w3} ⋅(\theta_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
# l1}⋅α⋅(1 - δ) + \theta_{l2}⋅(1 - α)⋅(1 - δ) + δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#         2                     ⎛        2            2             2
# 1 - α)))                     -⎝\sigma_w ⋅\theta_{l2}  - 2⋅\sigma_w ⋅\theta_{l2
# ─────────                    ─────────────────────────────────────────────────
#
#
#             (1 - α)⋅(1 - δ)⋅ℯ
# ───────── + ──────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#               2  2                       2  2                         2
# }⋅θ + \sigma_w ⋅θ  + \sigma_{\theta_{l2}} ⋅w  - 2⋅\sigma_{\theta_{l2}} ⋅w⋅w₂ +
# ──────────────────────────────────────────────────────────────────────────────
#                       2                     2
#             2⋅\sigma_w ⋅\sigma_{\theta_{l2}}
#
# ──────────────────────────────────────────────────────────────────────────────
#        _________________________________
#       ╱         2                     2
# 2⋅π⋅╲╱  \sigma_w ⋅\sigma_{\theta_{l2}}
#
#
#
#
#
#                      2   2⎞ ⎞
#  \sigma_{\theta_{l2}} ⋅w₂ ⎠ ⎟
# ────────────────────────────⎟
#                             ⎟
#                             ⎟
#                             ⎟
# ────────────────────────────⎟⋅(-\theta_{l1}⋅α⋅(1 - δ) - \theta_{l2}⋅(1 - α)⋅(1
#                             ⎟
#                             ⎟
#                             ⎠
#
#
#
#
#
#
#
#
#
#
#                                                     2
#  - δ) - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)) + θ) ⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  + w₂⋅(1 - α)) + w - w₂⋅(1 - α)⋅(1 - δ)) dw dθ

# %% [markdown]
# The equation in the document is:

# %%
display(sp.Eq(sym.w_prime_theta_prime_l_2_bar, c_f.w_prime_theta_l_prime_2_bar()))
# Out:
#                                                                      ⎛
#                             \overline{\theta_l'__3}⋅\overline{w'__2}⋅⎝1 - \til
# \overline{w'\theta'_l}__2 = ──────────────────────────────────────────────────
#                                             3⋅\overline{w'\theta'_l}⋅(-\lambda
#
#
#
#             2⎞                                              2
# de{\sigma}_w ⎠⋅(-\lambda_w⋅δ + 1)   2⋅\overline{w'\theta'_l} ⋅\overline{w'__3}
# ───────────────────────────────── + ──────────────────────────────────────────
# _{w\theta}⋅δ + 1)
#                                                          2 ⎛
#                                        3⋅\overline{w'__2} ⋅⎝1 - \tilde{\sigma}
#
#                            2
# ⋅(-\lambda_{w\theta}⋅δ + 1)
# ────────────────────────────
#     2
#   2⎞                    2
# _w ⎠ ⋅(-\lambda_w⋅δ + 1)

# %% [markdown]
# For this we still need $\tilde{\sigma_w}$:

# %%
display(sp.Eq(sym.sigma_tilde_w, c_f.sigma_tilde_w()))
# Out:
#                                      \sigma_w
# \tilde{\sigma}_w = ───────────────────────────────────────────
#                                             __________________
#                      __________________    ╱ -\lambda_w⋅δ + 1
#                    ╲╱ \overline{w'__2} ⋅  ╱  ────────────────
#                                         ╲╱        1 - δ

# %% [markdown]
# And $\overline{w'^{2}}$:

# %%
display(sp.Eq(sym.w_prime_2_bar, c_f.w_prime_2_bar()))
# Out:
#                               2               ⎛        2
# \overline{w'__2} = \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁
#
#  2⎞                   ⎛        2                       2⎞
# ) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠

# %% [markdown]
# And $\overline{w'^{3}}$:

# %%
display(sp.Eq(sym.w_prime_3_bar, c_f.w_prime_3_bar()))
# Out:
#                              ⎛          2
# \overline{w'__3} = α⋅(1 - δ)⋅⎝3⋅\sigma_w ⋅(-\overline{w} + w₁) + (-\overline{w
#
#        3⎞                   ⎛          2
# } + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝3⋅\sigma_w ⋅(-\overline{w} + w₂) + (-\overline{w}
#
#       3⎞
#  + w₂) ⎠

# %% [markdown]
# And $\overline{w'\theta'_l}$:

# %%
display(sp.Eq(sym.w_prime_theta_l_prime_bar, c_f.w_prime_theta_l_prime_bar()))
# Out:
# \overline{w'\theta'_l} = \rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅δ +
# α⋅(1 - δ)⋅(-\overline{\theta_l} + \theta_{l1})⋅(-\overline{w} + w₁) + (1 - α)⋅
# (1 - δ)⋅(-\overline{\theta_l} + \theta_{l2})⋅(-\overline{w} + w₂)

# %% [markdown]
# And $\lambda_w$:

# %%
display(sp.Eq(sym.lambda_w, c_f.lambda_w()))
# Out:
#                          2
#               \sigma_{w3}
# \lambda_w = ────────────────
#             \overline{w'__2}

# %% [markdown]
# And $\lambda_{w\theta}$:

# %%
display(sp.Eq(sym.lambda_w_theta, c_f.lambda_w_theta()))
# Out:
#                     \rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}
# \lambda_{w\theta} = ────────────────────────────────────────────────
#                                  \overline{w'\theta'_l}

# %% [markdown]
# And $\overline{\theta_l'^3}$:

# %%
display(sp.Eq(sym.theta_l_prime_3_bar, c_f.theta_l_prime_3_bar()))
# Out:
#                                     ⎛                      2
# \overline{\theta_l'__3} = α⋅(1 - δ)⋅⎝3⋅\sigma_{\theta_{l1}} ⋅(-\overline{\thet
#
#                                                           3⎞
# a_l} + \theta_{l1}) + (-\overline{\theta_l} + \theta_{l1}) ⎠ + (1 - α)⋅(1 - δ)
#
#  ⎛                      2
# ⋅⎝3⋅\sigma_{\theta_{l2}} ⋅(-\overline{\theta_l} + \theta_{l2}) + (-\overline{\
#
#                        3⎞
# theta_l} + \theta_{l2}) ⎠

# %% [markdown]
# Putting those all together yields:

# %%
w_prime_theta_l_prime_2_bar_check_val = c_f.w_prime_theta_l_prime_2_bar().subs({
    sym.theta_l_prime_3_bar: c_f.theta_l_prime_3_bar(),
    sym.sigma_tilde_w: c_f.sigma_tilde_w(),
    sym.lambda_w: c_f.lambda_w(),
    sym.w_prime_2_bar: c_f.w_prime_2_bar(),
    sym.w_prime_3_bar: c_f.w_prime_3_bar(),
    sym.lambda_w_theta: c_f.lambda_w_theta(),
    sym.w_prime_theta_l_prime_bar: c_f.w_prime_theta_l_prime_bar()
})

w_prime_theta_l_prime_2_bar_check_val = w_prime_theta_l_prime_2_bar_check_val.subs({
    sym.w_prime_2_bar: c_f.w_prime_2_bar(),
    sym.lambda_w: c_f.lambda_w(),
    sym.w_bar: c_f.w_bar(),
    sym.theta_l_bar: c_f.theta_l_bar()
})

display(sp.Eq(sym.w_prime_theta_prime_l_2_bar, w_prime_theta_l_prime_2_bar_check_val))
# Out:
#                             ⎛
#                             ⎜
#                             ⎜- ───────────────────────────────────────────────
#                             ⎜             2               ⎛        2
#                             ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅
#
#
#
# \overline{w'\theta'_l}__2 = ──────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                                                             2
#                                                  \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#                                                           2⎞
# (1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)⋅(1 - δ)
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#  ⎛        2
# ⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#        ⎞
#        ⎟ ⎛          ⎛                      2
# ─── + 1⎟⋅⎝α⋅(1 - δ)⋅⎝3⋅\sigma_{\theta_{l1}} ⋅(-\theta_{l1}⋅α⋅(1 - δ) + \theta_
#  2⎞    ⎟
# ) ⎠    ⎠
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                  ⎛
#                                                3⋅⎜- ──────────────────────────
#                                                  ⎝  \rho_{w\theta_l}⋅\sigma_{\
#
#
#
#
#
#
#
#
#
# {l1} - \theta_{l2}⋅(1 - α)⋅(1 - δ) - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)))
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
# theta_l 3}⋅\sigma_{w3}⋅δ + α⋅(1 - δ)⋅(-\theta_{l1}⋅α⋅(1 - δ) + \theta_{l1} - \
#
#
#
#
#
#
#
#
#
# + (-\theta_{l1}⋅α⋅(1 - δ) + \theta_{l1} - \theta_{l2}⋅(1 - α)⋅(1 - δ) - δ⋅(\th
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
# theta_{l2}⋅(1 - α)⋅(1 - δ) - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)))⋅(-α⋅w₁⋅(
#
#
#
#
#
#
#
#
#                                   3⎞                   ⎛
# eta_{l1}⋅α + \theta_{l2}⋅(1 - α))) ⎠ + (1 - α)⋅(1 - δ)⋅⎝3⋅\sigma_{\theta_{l2}}
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#           \rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅δ
# ──────────────────────────────────────────────────────────────────────────────
# 1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) + (1 - α)⋅(1 - δ)⋅(-
#
#
#
#
#
#
#
#
# 2
#  ⋅(-\theta_{l1}⋅α⋅(1 - δ) - \theta_{l2}⋅(1 - α)⋅(1 - δ) + \theta_{l2} - δ⋅(\th
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
# \theta_{l1}⋅α⋅(1 - δ) - \theta_{l2}⋅(1 - α)⋅(1 - δ) + \theta_{l2} - δ⋅(\theta_
#
#
#
#
#
#
#
#
#
# eta_{l1}⋅α + \theta_{l2}⋅(1 - α))) + (-\theta_{l1}⋅α⋅(1 - δ) - \theta_{l2}⋅(1
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────────────
# {l1}⋅α + \theta_{l2}⋅(1 - α)))⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1
#
#
#
#
#
#
#
#                                                                          ⎛
#                                                                      3⎞⎞ ⎜
# - α)⋅(1 - δ) + \theta_{l2} - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α))) ⎠⎠⋅⎜- ──
#                                                                          ⎜  ⎛
#                                                                          ⎜  ⎜
#                                                                          ⎜  ⎜-
#                                                                          ⎜  ⎜
#                                                                          ⎝  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                       ⎞
# ────────────────── + 1⎟⋅(\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅δ +
# - α)⋅(1 - δ) + w₂)    ⎠
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ─────────────────────────────────────────────────────────────────────────────
#             2               ⎛        2
#  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)
# ──────────────────────────────────────────────────────────────────────────────
#
# α⋅(1 - δ)⋅(-\theta_{l1}⋅α⋅(1 - δ) + \theta_{l1} - \theta_{l2}⋅(1 - α)⋅(1 - δ)
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                               2
#                    \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#                             2⎞                   ⎛        2
# ) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) -
# ──────────────────────────────────────────────────────────────────────────────
#
# - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)))⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 -
#
#
#
#
#
#
#
#
#                                                      2
#                                              \sigma_w ⋅(1 - δ)
# ──────────────────────────────────────────────────────────────────────────────
#                                                        ⎞
#                                                        ⎟ ⎛           2
# ─────────────────────────────────────────────────── + 1⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(
#                                                  2⎞    ⎟
#  δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂) ⎠    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
# α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) + (1 - α)⋅(1 - δ)⋅(-\theta_{l1}⋅α⋅(1 - δ) - \th
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#        ⎛        2
# 1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# eta_{l2}⋅(1 - α)⋅(1 - δ) + \theta_{l2} - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#        2⎞                   ⎛        2
# 1 - δ)) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# )))⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂))
#
#
#
#
#
#
#
#
#                                    ⎞
#                                    ⎟ ⎛           2               ⎛        2
# ─────────────────────────────── + 1⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  +
#                                    ⎟
#                             2⎞⎞    ⎟
# ) - w₂⋅(1 - α)⋅(1 - δ) + w₂) ⎠⎠    ⎟
#                                    ⎟
#                                    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                                                  2⎞
# (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)⋅
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#         ⎛        2
# (1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 -
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#         2⎞⎞
# δ) + w₂) ⎠⎠
#
#
#                 ⎛          ⎛          2
#               2⋅⎝α⋅(1 - δ)⋅⎝3⋅\sigma_w ⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α))
#
# ─────────── + ────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  + w₁ - w₂⋅(1 - α)⋅(1 - δ)) + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                  3⎞                   ⎛          2
# ⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)⋅(1 - δ)⋅⎝3⋅\sigma_w ⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ +
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                     ⎛
#                                     ⎜
#                                   3⋅⎜- ───────────────────────────────────────
#                                     ⎜             2               ⎛        2
#                                     ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  +
#
#
#
#
#
#
#
#
#
#
# w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂) + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                     2
#                                                          \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#                                                                   2⎞
#  (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)
#
#
#
#
#
#
#
#
#
#                             3⎞⎞ ⎛
# ) - w₂⋅(1 - α)⋅(1 - δ) + w₂) ⎠⎠⋅⎜- ───────────────────────────────────────────
#                                 ⎝  \rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#          ⎛        2
# ⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 -
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# _{w3}⋅δ + α⋅(1 - δ)⋅(-\theta_{l1}⋅α⋅(1 - δ) + \theta_{l1} - \theta_{l2}⋅(1 - α
# ──────────────────────────────────────────────────────────────────────────────
#                 2
#                ⎞  ⎛
#                ⎟  ⎜
# ─────────── + 1⎟ ⋅⎜- ─────────────────────────────────────────────────────────
#          2⎞    ⎟  ⎜  ⎛
#  δ) + w₂) ⎠    ⎠  ⎜  ⎜
#                   ⎜  ⎜- ──────────────────────────────────────────────────────
#                   ⎜  ⎜             2               ⎛        2
#                   ⎝  ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ)
#
#
#
#
#
#
#                                                                        \rho_{w
# ──────────────────────────────────────────────────────────────────────────────
# )⋅(1 - δ) - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)))⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2
#                                           \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#                                                    2⎞                   ⎛
#  - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigm
#
#
#
#
#
#
# \theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅δ
# ──────────────────────────────────────────────────────────────────────────────
# + w₂⋅(1 - α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) + (1 - α)⋅(1 - δ)⋅(-\theta_{l1}⋅α⋅(1
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                             2
#                                                                     \sigma_w ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ────────────────────────────────────────────────────────────────────────── + 1
#    2                                                                    2⎞
# a_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂) ⎠
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# - δ) - \theta_{l2}⋅(1 - α)⋅(1 - δ) + \theta_{l2} - δ⋅(\theta_{l1}⋅α + \theta_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
# (1 - δ)
# ──────────────────────────────────────────────────────────────────────────────
# ⎞
# ⎟ ⎛           2               ⎛        2
# ⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 -
# ⎟
# ⎠
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
# l2}⋅(1 - α)))⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                               2⎞                   ⎛        2
# α)) + w₁ - w₂⋅(1 - α)⋅(1 - δ)) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ)
#
#
#
#
#
#
#
#       2
#      ⎞
# ─ + 1⎟ ⋅(\rho_{w\theta_l}⋅\sigma_{\theta_l 3}⋅\sigma_{w3}⋅δ + α⋅(1 - δ)⋅(-\the
# )    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                            2
#                                                           ⎞
#                                                           ⎟  ⎛           2
# ────────────────────────────────────────────────────── + 1⎟ ⋅⎝\sigma_{w3} ⋅δ +
#                                                           ⎟
#                                                    2⎞⎞    ⎟
#  - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂) ⎠⎠    ⎟
#                                                           ⎟
#                                                           ⎠
#
#
#
#
#
#
#
# ta_{l1}⋅α⋅(1 - δ) + \theta_{l1} - \theta_{l2}⋅(1 - α)⋅(1 - δ) - δ⋅(\theta_{l1}
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            ⎛        2
#  α⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1 -
#
#
#
#
#
#
#
#
#
#
#
#
# ⋅α + \theta_{l2}⋅(1 - α)))⋅(-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) + w₁ - w₂⋅(1
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#            2⎞                   ⎛        2
# α)⋅(1 - δ)) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-α⋅w₁⋅(1 - δ) - δ⋅(α⋅w₁ + w₂⋅(1
#
#
#
#
#
#
#
#
#
#
#
#
#  - α)⋅(1 - δ)) + (1 - α)⋅(1 - δ)⋅(-\theta_{l1}⋅α⋅(1 - δ) - \theta_{l2}⋅(1 - α)
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                                    2
#                                 2⎞⎞
# - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂) ⎠⎠
#
#
#
#
#
#
#
#
#
#
#
#
# ⋅(1 - δ) + \theta_{l2} - δ⋅(\theta_{l1}⋅α + \theta_{l2}⋅(1 - α)))⋅(-α⋅w₁⋅(1 -
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       2
# δ) - δ⋅(α⋅w₁ + w₂⋅(1 - α)) - w₂⋅(1 - α)⋅(1 - δ) + w₂))
#
# ───────────────────────────────────────────────────────

# %% [markdown]
# Since the integral is too difficult to be calculated analytically, at least with sympy, we try to put in some arbitrary numbers for the pdf parameters, to simplify the equations.

# %% [markdown]
# We create a dataframe to get all possible permutations and therefore also all possible evaluations of the integrals.

# %%
df = pd.DataFrame(
    product([0, 1],
            [-2, 2],
            [-1, 2],
            [0, 3],
            [Rational(1, 10)],
            [Rational(3, 10)],
            [Rational(4, 10)],
            [Rational(7, 10)],
            [Rational(6, 10)],
            [Rational(5, 10)],
            [Rational(1, 10), Rational(5, 10)],
            [Rational(5, 10)]),
    columns=[sym.w_1,
             sym.w_2,
             sym.theta_l_1,
             sym.theta_l_2,
             sym.sigma_theta_l_1,
             sym.sigma_theta_l_2,
             sym.sigma_theta_l_3,
             sym.sigma_w,
             sym.sigma_w_3,
             sp.abc.alpha,
             sp.abc.delta,
             sym.rho_w_theta_l])

# %%
df['check_val'] = (
    df.apply(lambda x:
             w_prime_theta_l_prime_2_bar_check_val.subs({
                 sym.w_1: x[sym.w_1],
                 sym.w_2: x[sym.w_2],
                 sym.theta_l_1: x[sym.theta_l_1],
                 sym.theta_l_2: x[sym.theta_l_2],
                 sym.sigma_theta_l_1: x[sym.sigma_theta_l_1],
                 sym.sigma_theta_l_2: x[sym.sigma_theta_l_2],
                 sym.sigma_theta_l_3: x[sym.sigma_theta_l_3],
                 sym.sigma_w: x[sym.sigma_w],
                 sym.sigma_w_3: x[sym.sigma_w_3],
                 sp.abc.alpha: x[sp.abc.alpha],
                 sp.abc.delta: x[sp.abc.delta],
                 sym.rho_w_theta_l: x[sym.rho_w_theta_l]
             }).evalf(), axis=1))

# %% [markdown]
# Calculate the moment analytically:

# %%
df['num_int'] = (
    df.apply(lambda x: w_prime_theta_l_2_prime_bar.subs({
        sym.w_1: x[sym.w_1],
        sym.w_2: x[sym.w_2],
        sym.theta_l_1: x[sym.theta_l_1],
        sym.theta_l_2: x[sym.theta_l_2],
        sym.sigma_theta_l_1: x[sym.sigma_theta_l_1],
        sym.sigma_theta_l_2: x[sym.sigma_theta_l_2],
        sym.sigma_theta_l_3: x[sym.sigma_theta_l_3],
        sym.sigma_w: x[sym.sigma_w],
        sym.sigma_w_3: x[sym.sigma_w_3],
        sp.abc.alpha: x[sp.abc.alpha],
        sp.abc.delta: x[sp.abc.delta],
        sym.rho_w_theta_l: x[sym.rho_w_theta_l]
    }).doit(conds='none', method='quad').evalf(), axis=1))

# %%
df['diff'] = abs(df['check_val'] - df['num_int'])

# %%
df['diff_num'] = abs(df['check_val'].astype(float) - df['num_int'].astype(float))

# %%
display(df)
# Out:
#     w_1  w_2  \theta_{l1}  \theta_{l2} \sigma_{\theta_{l1}}  \
# 0     0   -2           -1            0                 1/10
# 1     0   -2           -1            0                 1/10
# 2     0   -2           -1            3                 1/10
# 3     0   -2           -1            3                 1/10
# 4     0   -2            2            0                 1/10
# 5     0   -2            2            0                 1/10
# 6     0   -2            2            3                 1/10
# 7     0   -2            2            3                 1/10
# 8     0    2           -1            0                 1/10
# 9     0    2           -1            0                 1/10
# 10    0    2           -1            3                 1/10
# 11    0    2           -1            3                 1/10
# 12    0    2            2            0                 1/10
# 13    0    2            2            0                 1/10
# 14    0    2            2            3                 1/10
# 15    0    2            2            3                 1/10
# 16    1   -2           -1            0                 1/10
# 17    1   -2           -1            0                 1/10
# 18    1   -2           -1            3                 1/10
# 19    1   -2           -1            3                 1/10
# 20    1   -2            2            0                 1/10
# 21    1   -2            2            0                 1/10
# 22    1   -2            2            3                 1/10
# 23    1   -2            2            3                 1/10
# 24    1    2           -1            0                 1/10
# 25    1    2           -1            0                 1/10
# 26    1    2           -1            3                 1/10
# 27    1    2           -1            3                 1/10
# 28    1    2            2            0                 1/10
# 29    1    2            2            0                 1/10
# 30    1    2            2            3                 1/10
# 31    1    2            2            3                 1/10
#
#    \sigma_{\theta_{l2}} \sigma_{\theta_l 3} \sigma_w \sigma_{w3} alpha delta  \
# 0                  3/10                 2/5     7/10         3/5   1/2  1/10
# 1                  3/10                 2/5     7/10         3/5   1/2   1/2
# 2                  3/10                 2/5     7/10         3/5   1/2  1/10
# 3                  3/10                 2/5     7/10         3/5   1/2   1/2
# 4                  3/10                 2/5     7/10         3/5   1/2  1/10
# 5                  3/10                 2/5     7/10         3/5   1/2   1/2
# 6                  3/10                 2/5     7/10         3/5   1/2  1/10
# 7                  3/10                 2/5     7/10         3/5   1/2   1/2
# 8                  3/10                 2/5     7/10         3/5   1/2  1/10
# 9                  3/10                 2/5     7/10         3/5   1/2   1/2
# 10                 3/10                 2/5     7/10         3/5   1/2  1/10
# 11                 3/10                 2/5     7/10         3/5   1/2   1/2
# 12                 3/10                 2/5     7/10         3/5   1/2  1/10
# 13                 3/10                 2/5     7/10         3/5   1/2   1/2
# 14                 3/10                 2/5     7/10         3/5   1/2  1/10
# 15                 3/10                 2/5     7/10         3/5   1/2   1/2
# 16                 3/10                 2/5     7/10         3/5   1/2  1/10
# 17                 3/10                 2/5     7/10         3/5   1/2   1/2
# 18                 3/10                 2/5     7/10         3/5   1/2  1/10
# 19                 3/10                 2/5     7/10         3/5   1/2   1/2
# 20                 3/10                 2/5     7/10         3/5   1/2  1/10
# 21                 3/10                 2/5     7/10         3/5   1/2   1/2
# 22                 3/10                 2/5     7/10         3/5   1/2  1/10
# 23                 3/10                 2/5     7/10         3/5   1/2   1/2
# 24                 3/10                 2/5     7/10         3/5   1/2  1/10
# 25                 3/10                 2/5     7/10         3/5   1/2   1/2
# 26                 3/10                 2/5     7/10         3/5   1/2  1/10
# 27                 3/10                 2/5     7/10         3/5   1/2   1/2
# 28                 3/10                 2/5     7/10         3/5   1/2  1/10
# 29                 3/10                 2/5     7/10         3/5   1/2   1/2
# 30                 3/10                 2/5     7/10         3/5   1/2  1/10
# 31                 3/10                 2/5     7/10         3/5   1/2   1/2
#
#    \rho_{w\theta_l}            check_val              num_int diff  diff_num
# 0               1/2  -0.0360000000000000  -0.0360000000000000    0       0.0
# 1               1/2  -0.0200000000000000  -0.0200000000000000    0       0.0
# 2               1/2  -0.0360000000000000  -0.0360000000000000    0       0.0
# 3               1/2  -0.0200000000000000  -0.0200000000000000    0       0.0
# 4               1/2  -0.0360000000000000  -0.0360000000000000    0       0.0
# 5               1/2  -0.0200000000000000  -0.0200000000000000    0       0.0
# 6               1/2  -0.0360000000000000  -0.0360000000000000    0       0.0
# 7               1/2  -0.0200000000000000  -0.0200000000000000    0       0.0
# 8               1/2   0.0360000000000000   0.0360000000000000    0       0.0
# 9               1/2   0.0200000000000000   0.0200000000000000    0       0.0
# 10              1/2   0.0360000000000000   0.0360000000000000    0       0.0
# 11              1/2   0.0200000000000000   0.0200000000000000    0       0.0
# 12              1/2   0.0360000000000000   0.0360000000000000    0       0.0
# 13              1/2   0.0200000000000000   0.0200000000000000    0       0.0
# 14              1/2   0.0360000000000000   0.0360000000000000    0       0.0
# 15              1/2   0.0200000000000000   0.0200000000000000    0       0.0
# 16              1/2  -0.0540000000000000  -0.0540000000000000    0       0.0
# 17              1/2  -0.0300000000000000  -0.0300000000000000    0       0.0
# 18              1/2  -0.0540000000000000  -0.0540000000000000    0       0.0
# 19              1/2  -0.0300000000000000  -0.0300000000000000    0       0.0
# 20              1/2  -0.0540000000000000  -0.0540000000000000    0       0.0
# 21              1/2  -0.0300000000000000  -0.0300000000000000    0       0.0
# 22              1/2  -0.0540000000000000  -0.0540000000000000    0       0.0
# 23              1/2  -0.0300000000000000  -0.0300000000000000    0       0.0
# 24              1/2   0.0180000000000000   0.0180000000000000    0       0.0
# 25              1/2   0.0100000000000000   0.0100000000000000    0       0.0
# 26              1/2   0.0180000000000000   0.0180000000000000    0       0.0
# 27              1/2   0.0100000000000000   0.0100000000000000    0       0.0
# 28              1/2   0.0180000000000000   0.0180000000000000    0       0.0
# 29              1/2   0.0100000000000000   0.0100000000000000    0       0.0
# 30              1/2   0.0180000000000000   0.0180000000000000    0       0.0
# 31              1/2   0.0100000000000000   0.0100000000000000    0       0.0

# %%
import numpy as np

print('The mean error between the rhs and the lhs is:', np.mean(df['diff_num']))
# Out:
# The mean error between the rhs and the lhs is: 0.0
