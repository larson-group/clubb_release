# %%
import sympy as sp
from IPython.display import display
from sympy import abc, oo, init_printing

import checked_functions as c_f
import symbols as sym
init_printing()

# %% [markdown]
# # This document aims to analytically check $\overline{w'^4}$

# %% [markdown]
# ## Define the marginal distributions with those parameters.

# %%
display(sp.Eq(sym.G_1_w, c_f.G_1_theta_l_density))
# Out:
#                                         2
#                 -(\thetaₗ - \theta_{l1})
#                 ──────────────────────────
#                                        2
#                  2⋅\sigma_{\theta_{l1}}
#             √2⋅ℯ
# G_{1w}(w) = ──────────────────────────────
#               2⋅√π⋅\sigma_{\theta_{l1}}

# %%
display(sp.Eq(sym.G_2_w, c_f.G_2_theta_l_density))
# Out:
#                                         2
#                 -(\thetaₗ - \theta_{l2})
#                 ──────────────────────────
#                                        2
#                  2⋅\sigma_{\theta_{l2}}
#             √2⋅ℯ
# G_{2w}(w) = ──────────────────────────────
#               2⋅√π⋅\sigma_{\theta_{l2}}

# %%
display(sp.Eq(sym.G_3_w, c_f.G_3_theta_l_density))
# Out:
#                                                  2
#                 -(-\overline{\theta_l} + \thetaₗ)
#                 ───────────────────────────────────
#                                             2
#                        2⋅\sigma_{\theta_l 3}
#             √2⋅ℯ
# G_{3w}(w) = ───────────────────────────────────────
#                     2⋅√π⋅\sigma_{\theta_l 3}

# %%
display(sp.Eq(sym.G_w, c_f.G_w))
# Out:
#                                      2                           2
#                  -(-\overline{w} + w)                   -(w - w₁)
#                  ──────────────────────                 ───────────
#                                   2                               2
#                      2⋅\sigma_{w3}                      2⋅\sigma_w
#            √2⋅δ⋅ℯ                         √2⋅α⋅(1 - δ)⋅ℯ              √2⋅(1 -
# G_{w}(w) = ──────────────────────────── + ───────────────────────── + ────────
#                  2⋅√π⋅\sigma_{w3}               2⋅√π⋅\sigma_w
#
#                      2
#             -(w - w₂)
#             ───────────
#                       2
#             2⋅\sigma_w
# α)⋅(1 - δ)⋅ℯ
# ───────────────────────
#  2⋅√π⋅\sigma_w

# %% [markdown]
# Calculate the moment analytically:

# %%
w_prime_4_bar_int = sp.Integral((sp.abc.w - sym.w_bar) ** 4 * c_f.G_w, [sp.abc.w, -oo, oo])
display(sp.Eq(sym.w_prime_4_bar, w_prime_4_bar_int))
# Out:
#                    ∞
#                    ⌠
#                    ⎮                       ⎛                          2
#                    ⎮                       ⎜      -(-\overline{w} + w)
#                    ⎮                       ⎜      ──────────────────────
#                    ⎮                       ⎜                       2
#                    ⎮                       ⎜          2⋅\sigma_{w3}
#                    ⎮                     4 ⎜√2⋅δ⋅ℯ                         √2⋅
# \overline{w'__4} = ⎮  (-\overline{w} + w) ⋅⎜──────────────────────────── + ───
#                    ⎮                       ⎝      2⋅√π⋅\sigma_{w3}
#                    ⌡
#                    -∞
#
#
#
#                     2                                 2 ⎞
#            -(w - w₁)                         -(w - w₂)  ⎟
#            ───────────                       ───────────⎟
#                      2                                 2⎟
#            2⋅\sigma_w                        2⋅\sigma_w ⎟
# α⋅(1 - δ)⋅ℯ              √2⋅(1 - α)⋅(1 - δ)⋅ℯ           ⎟
# ────────────────────── + ───────────────────────────────⎟ dw
#    2⋅√π⋅\sigma_w                  2⋅√π⋅\sigma_w         ⎠

# %%
w_prime_4_bar_int_val = w_prime_4_bar_int.doit(conds='none').simplify()
display(sp.Eq(sym.w_prime_4_bar, w_prime_4_bar_int_val))
# Out:
#                                  4                 4                 3
# \overline{w'__4} = - \overline{w} ⋅δ + \overline{w}  + 4⋅\overline{w} ⋅α⋅δ⋅w₁
#
#                 3                        3                      3
# - 4⋅\overline{w} ⋅α⋅δ⋅w₂ - 4⋅\overline{w} ⋅α⋅w₁ + 4⋅\overline{w} ⋅α⋅w₂ + 4⋅\ov
#
#          3                      3                    2         2
# erline{w} ⋅δ⋅w₂ - 4⋅\overline{w} ⋅w₂ - 6⋅\overline{w} ⋅\sigma_w ⋅δ + 6⋅\overli
#
#      2         2                 2       2                 2       2
# ne{w} ⋅\sigma_w  - 6⋅\overline{w} ⋅α⋅δ⋅w₁  + 6⋅\overline{w} ⋅α⋅δ⋅w₂  + 6⋅\over
#
#        2     2                 2     2                 2     2
# line{w} ⋅α⋅w₁  - 6⋅\overline{w} ⋅α⋅w₂  - 6⋅\overline{w} ⋅δ⋅w₂  + 6⋅\overline{w
#
#  2   2                           2                                  2
# } ⋅w₂  + 12⋅\overline{w}⋅\sigma_w ⋅α⋅δ⋅w₁ - 12⋅\overline{w}⋅\sigma_w ⋅α⋅δ⋅w₂ -
#
#                          2                                2
#  12⋅\overline{w}⋅\sigma_w ⋅α⋅w₁ + 12⋅\overline{w}⋅\sigma_w ⋅α⋅w₂ + 12⋅\overlin
#
#              2                                2                           3
# e{w}⋅\sigma_w ⋅δ⋅w₂ - 12⋅\overline{w}⋅\sigma_w ⋅w₂ + 4⋅\overline{w}⋅α⋅δ⋅w₁  -
#
#                      3                      3                      3
# 4⋅\overline{w}⋅α⋅δ⋅w₂  - 4⋅\overline{w}⋅α⋅w₁  + 4⋅\overline{w}⋅α⋅w₂  + 4⋅\over
#
#             3                    3             4               4             2
# line{w}⋅δ⋅w₂  - 4⋅\overline{w}⋅w₂  - 3⋅\sigma_w ⋅δ + 3⋅\sigma_w  - 6⋅\sigma_w
#
#        2             2       2             2     2             2     2
# ⋅α⋅δ⋅w₁  + 6⋅\sigma_w ⋅α⋅δ⋅w₂  + 6⋅\sigma_w ⋅α⋅w₁  - 6⋅\sigma_w ⋅α⋅w₂  - 6⋅\si
#
#      2     2             2   2                4           4         4       4
# gma_w ⋅δ⋅w₂  + 6⋅\sigma_w ⋅w₂  + 3⋅\sigma_{w3} ⋅δ - α⋅δ⋅w₁  + α⋅δ⋅w₂  + α⋅w₁
#
#       4       4     4
# - α⋅w₂  - δ⋅w₂  + w₂

# %% [markdown]
# The equation in the document is:

# %%
display(sp.Eq(sym.w_prime_4_bar, c_f.w_prime_4_bar()))
# Out:
#                                                            2
#                                      ⎛                2   ⎞  ⎛
#                                    2 ⎜     \sigma_{w3} ⋅δ ⎟  ⎜
#                    \overline{w'__2} ⋅⎜1 - ────────────────⎟ ⋅⎝3⋅\tilde{\sigma}
#                                      ⎝    \overline{w'__2}⎠
# \overline{w'__4} = ───────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                            2⎞
#   4                   2 ⎛                      2⎞   ⎛                    2⎞ ⎟
# _w  + \tilde{\sigma}_w ⋅⎝6 - 6⋅\tilde{\sigma}_w ⎠ + ⎝1 - \tilde{\sigma}_w ⎠ ⎠
#
# ─────────────────────────────────────────────────────────────────────────────
#       1 - δ
#
#
#
#
#
#
#
#                                                             2
#                4                            \overline{w'__3}
# + 3⋅\sigma_{w3} ⋅δ + ─────────────────────────────────────────────────────────
#                                                               ⎛
#                                       ⎛                    2⎞ ⎜     \sigma_{w3
#                      \overline{w'__2}⋅⎝1 - \tilde{\sigma}_w ⎠⋅⎜1 - ───────────
#                                                               ⎝    \overline{w
#
#
#
#
#
#
# ──────
#  2   ⎞
# } ⋅δ ⎟
# ─────⎟
# '__2}⎠

# %% [markdown]
# where

# %%
display(sp.Eq(sym.sigma_tilde_w, c_f.sigma_tilde_w()))
# Out:
#                                      \sigma_w
# \tilde{\sigma}_w = ───────────────────────────────────────────
#                                             __________________
#                      __________________    ╱ -\lambda_w⋅δ + 1
#                    ╲╱ \overline{w'__2} ⋅  ╱  ────────────────
#                                         ╲╱        1 - δ

# %% [markdown]
# and

# %%
display(sp.Eq(sym.w_prime_2_bar, c_f.w_prime_2_bar()))
# Out:
#                               2               ⎛        2
# \overline{w'__2} = \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁
#
#  2⎞                   ⎛        2                       2⎞
# ) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠

# %% [markdown]
# and

# %%
display(sp.Eq(sym.w_prime_3_bar, c_f.w_prime_2_bar()))
# Out:
#                               2               ⎛        2
# \overline{w'__3} = \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁
#
#  2⎞                   ⎛        2                       2⎞
# ) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠

# %% [markdown]
# So,

# %%
lambda_w_val = c_f.lambda_w().subs({
    sym.w_prime_2_bar: c_f.w_prime_2_bar()
})
display(sp.Eq(sym.lambda_w, lambda_w_val))
# Out:
#                                                                            2
#                                                                 \sigma_{w3}
# \lambda_w = ──────────────────────────────────────────────────────────────────
#                        2               ⎛        2                       2⎞
#             \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (
#
#
#
# ──────────────────────────────────────────────────
#                ⎛        2                       2⎞
# 1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠

# %%
w_prime_4_bar_check_val = c_f.w_prime_4_bar().subs({
    sym.w_prime_2_bar: c_f.w_prime_2_bar(),
    sym.w_prime_3_bar: c_f.w_prime_3_bar(),
    sym.sigma_tilde_w: c_f.sigma_tilde_w().subs({
        sym.w_prime_2_bar: c_f.w_prime_2_bar(),
        sym.lambda_w: c_f.lambda_w()
    })
})

display(sp.Eq(sym.w_prime_4_bar, w_prime_4_bar_check_val))
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 4
# \overline{w'__4} = 3⋅\sigma_{w3} ⋅δ + ────────────────────────────────────────
#                                       ⎛
#                                       ⎜
#                                       ⎜- ─────────────────────────────────────
#                                       ⎜             2               ⎛        2
#                                       ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                          2
#               \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#                        2⎞                   ⎛        2                       2
#  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                         ⎛          ⎛
#                                                         ⎝α⋅(1 - δ)⋅⎝3⋅\sigma_w
# ──────────────────────────────────────────────────────────────────────────────
#      ⎞ ⎛
#      ⎟ ⎜
# ─ + 1⎟⋅⎜- ────────────────────────────────────────────────────────────────────
# ⎞    ⎟ ⎜  ⎛                                                                2
# ⎠    ⎠ ⎜  ⎜                                                     \sigma_{w3} ⋅δ
#        ⎜  ⎜- ─────────────────────────────────────────────────────────────────
#        ⎜  ⎜             2               ⎛        2                       2⎞
#        ⎝  ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ +
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2                                            3⎞                   ⎛          2
#  ⋅(-\overline{w} + w₁) + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝3⋅\sigma_w
# ──────────────────────────────────────────────────────────────────────────────
#                                                      2
#                                              \sigma_w ⋅(1 - δ)
# ──────────────────────────────────────────────────────────────────────────────
#                                                        ⎞
#                                                        ⎟ ⎛           2
# ─────────────────────────────────────────────────── + 1⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(
#                 ⎛        2                       2⎞    ⎟
# (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠    ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                2
#                                             3⎞⎞
# ⋅(-\overline{w} + w₂) + (-\overline{w} + w₂) ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#        ⎛        2                       2⎞                   ⎛        2
# 1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\o
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                        ⎞
#                        ⎟ ⎛           2               ⎛        2
# ─────────────────── + 1⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{
#                        ⎟
#                 2⎞⎞    ⎟
# verline{w} + w₂) ⎠⎠    ⎟
#                        ⎟
#                        ⎠
#
#
#
#
#
#
#
#                                                                     ⎛
#                                                                     ⎜
#                                                                     ⎜- ───────
#                                                                     ⎜
#                                                                     ⎝  \sigma_
#
#
#
#
# ───────────────────────────────────────────────────────────────── + ──────────
#
#         2⎞                   ⎛        2                       2⎞⎞
# w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠⎠
#
#
#
#
#
#
#
#
#
#
#
#
#                                                        2
#                                             \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#     2               ⎛        2                       2⎞                   ⎛
# {w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\si
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     2
#                                    ⎞
#                                    ⎟  ⎛           2               ⎛        2
# ─────────────────────────────── + 1⎟ ⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  +
#      2                       2⎞    ⎟
# gma_w  + (-\overline{w} + w₂) ⎠    ⎠
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      2⎞                   ⎛        2                       2⎞⎞
#  (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠⎠
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#   ⎛
#   ⎜
#   ⎜
#   ⎜
#   ⎜
#   ⎜
# 2 ⎜
#   ⎜
#  ⋅⎜───────────────────────────────────────────────────────────────────────────
#   ⎜
#   ⎜⎛                                                                2
#   ⎜⎜                                                     \sigma_{w3} ⋅δ
#   ⎜⎜- ────────────────────────────────────────────────────────────────────────
#   ⎜⎜             2               ⎛        2                       2⎞
#   ⎝⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 - α)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                 4        2
#                                       3⋅\sigma_w ⋅(1 - δ)
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                                 ⎞
#                                                 ⎟  ⎛           2
# ──────────────────────────────────────────── + 1⎟ ⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)
#          ⎛        2                       2⎞    ⎟
# ⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  ⎛        2                       2⎞                   ⎛        2
# ⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overlin
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#                                    ⎛
#                          2         ⎜
#                  \sigma_w ⋅(1 - δ)⋅⎜- ────────────────────────────────────────
#                                    ⎜  ⎛
#                                    ⎜  ⎜
#                                    ⎜  ⎜- ─────────────────────────────────────
#                                    ⎜  ⎜             2               ⎛        2
#                                    ⎝  ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w
# ────────────── + ─────────────────────────────────────────────────────────────
#                               ⎛
#              2                ⎜
#           2⎞⎞                 ⎜- ─────────────────────────────────────────────
# e{w} + w₂) ⎠⎠                 ⎜             2               ⎛        2
#                               ⎝  \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\ov
#
# ──────────────────────────────────────────────────────────────────────────────
#                              1 - δ
#
#
#
#
#
#
#
#
#
#                                                                         6⋅\sig
# ──────────────────────────────────────────────────────────────────────────────
#                          2
#               \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#                        2⎞                   ⎛        2                       2
#  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂)
# ──────────────────────────────────────────────────────────────────────────────
#                  2                                                         ⎞
#       \sigma_{w3} ⋅δ                                                       ⎟ ⎛
# ─────────────────────────────────────────────────────────────────────── + 1⎟⋅⎝
#                2⎞                   ⎛        2                       2⎞    ⎟
# erline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠    ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#     2
# ma_w ⋅(1 - δ)
# ──────────────────────────────────────────────────────────────────────────────
#      ⎞
#      ⎟ ⎛           2               ⎛        2                       2⎞
# ─ + 1⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 -
# ⎞    ⎟
# ⎠    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#            2               ⎛        2                       2⎞
# \sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 -
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#                                                    ⎞
#                                                    ⎟
# ─────────────────────────────────────────────── + 6⎟
#                                                    ⎟
#            ⎛        2                       2⎞⎞    ⎟
# α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠⎠    ⎟
#                                                    ⎟   ⎛
#                                                    ⎠   ⎜
# ──────────────────────────────────────────────────── + ⎜- ────────────────────
#                                                        ⎜  ⎛
#    ⎛        2                       2⎞⎞                ⎜  ⎜
# δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠⎠                ⎜  ⎜- ─────────────────
#                                                        ⎜  ⎜             2
#                                                        ⎝  ⎝  \sigma_{w3} ⋅δ +
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                              2
#                                   \sigma_{w3} ⋅δ
# ──────────────────────────────────────────────────────────────────────────────
#           ⎛        2                       2⎞                   ⎛        2
# α⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                        2
#                \sigma_w ⋅(1 - δ)
# ──────────────────────────────────────────────────────────────────────────────
#                          ⎞
#                          ⎟ ⎛           2               ⎛        2
# ───────────────────── + 1⎟⋅⎝\sigma_{w3} ⋅δ + α⋅(1 - δ)⋅⎝\sigma_w  + (-\overlin
#                    2⎞    ⎟
# -\overline{w} + w₂) ⎠    ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#                                                                          ⎞
#                                                                          ⎟
#                                                                          ⎟
#                                                                          ⎟
#                                                                          ⎟
#                                                                         2⎟
#                                                                        ⎞ ⎟
#                                                                        ⎟ ⎟
# ─────────────────────────────────────────────────────────────────── + 1⎟ ⎟
#                                                                        ⎟ ⎟
#           2⎞                   ⎛        2                       2⎞⎞    ⎟ ⎟
# e{w} + w₁) ⎠ + (1 - α)⋅(1 - δ)⋅⎝\sigma_w  + (-\overline{w} + w₂) ⎠⎠    ⎟ ⎟
#                                                                        ⎟ ⎟
#                                                                        ⎠ ⎟
#                                                                          ⎠
# ──────────────────────────────────────────────────────────────────────────

# %%
display(sp.Eq(w_prime_4_bar_int_val, w_prime_4_bar_check_val, evaluate=True)
        .subs({sym.w_bar: c_f.w_bar()}).simplify())
# Out:
# True
